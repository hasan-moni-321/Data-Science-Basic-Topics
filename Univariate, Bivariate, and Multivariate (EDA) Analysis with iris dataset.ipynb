# %% [markdown]
# # Univariate, Bivariate and Multivariate (EDA) Analysis

# %%
import numpy as  np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
iris = pd.read_csv('/home/hasan/DATA SET/iris/Iris.csv')

# %%
iris.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 4            5.0           3.6            1.4           0.2  Iris-setosa

# %%
iris.shape
# Out:
# (150, 5)

# %%
iris.Species.unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %% [markdown]
# # Univariate Data Analysis

# %% [markdown]
# Definition Univariate:
#     univariate takes only one feature

# %%
setosa_iris = iris.loc[iris['Species']=='Iris-setosa']
versicolor_iris = iris.loc[iris['Species']=='Iris-versicolor']
virginica_iris = iris.loc[iris['Species']=='Iris-virginica']

# %%
plt.plot(setosa_iris['PetalLengthCm'], np.zeros_like(setosa_iris['PetalLengthCm']),'o')
plt.plot(versicolor_iris['PetalLengthCm'], np.zeros_like(versicolor_iris['PetalLengthCm']),'o')
plt.plot(virginica_iris['PetalLengthCm'], np.zeros_like(virginica_iris['PetalLengthCm']),'o')
plt.xlabel('petal length')
plt.title('Univariate (EDA) Analysis')
# Out:
# Text(0.5, 1.0, 'Univariate (EDA) Analysis')

# %% [markdown]
# three class stayed in three place out have very few outlier

# %% [markdown]
# # Bivariate Data Analysis

# %% [markdown]
# definition of bivariate:-
#     in bivariate analysis we take only exactly two feature

# %%
sns.FacetGrid(iris, hue='Species', height=5).map(plt.scatter, 'PetalLengthCm', 'SepalWidthCm').add_legend()
plt.title('Bivariate data analysis')
# Out:
# Text(0.5, 1, 'Bivariate data analysis')

# %% [markdown]
# # Multivariate Data Analysis

# %% [markdown]
# definition of multivariate analysis:
#     in multivaritate data analysis it take more than two features

# %%
sns.pairplot(iris, hue='Species')
